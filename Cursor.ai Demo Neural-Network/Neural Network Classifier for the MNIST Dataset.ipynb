# %%
# Install required libraries
# !pip3 install tensorflow numpy matplotlib scikit-learn seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: numpy in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: scikit-learn in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: seaborn in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: packaging in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.67.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: libclang>=13.0.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: keras>=3.5.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: pillow>=8 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: pandas>=1.2 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: namex in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: rich in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import required libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Load and preprocess MNIST dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Build the neural network model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(X_train, y_train,
                    batch_size=32,
                    epochs=10,
                    validation_split=0.2,
                    verbose=1)

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'\nTest accuracy: {test_accuracy:.4f}')

# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Print classification report
print('\nClassification Report:')
print(classification_report(y_test, y_pred_classes))

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Display some example predictions
plt.figure(figsize=(15, 6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f'Pred: {y_pred_classes[i]}\nTrue: {y_test[i]}')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# /Users/rushabhrunwal/Library/Python/3.9/lib/python/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 873us/step - accuracy: 0.8030 - loss: 0.6280 - val_accuracy: 0.9586 - val_loss: 0.1415
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 883us/step - accuracy: 0.9466 - loss: 0.1811 - val_accuracy: 0.9674 - val_loss: 0.1084
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - accuracy: 0.9606 - loss: 0.1282 - val_accuracy: 0.9680 - val_loss: 0.1052
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9673 - loss: 0.1082 - val_accuracy: 0.9712 - val_loss: 0.0946
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - accuracy: 0.9723 - loss: 0.0929 - val_accuracy: 0.9728 - val_loss: 0.0906
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9724 - loss: 0.0885 - val_accuracy: 0.9736 - val_loss: 0.0882
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 824us/step - accuracy: 0.9763 - loss: 0.0762 - val_accuracy: 0.9758 - val_loss: 0.0829
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.9786 - loss: 0.0681 - val_accuracy: 0.9753 - val_loss: 0.0876
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 875us/step - accuracy: 0.9802 - loss: 0.0616 - val_accuracy: 0.9760 - val_loss: 0.0853
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 839us/step - accuracy: 0.9815 - loss: 0.0591 - val_accuracy: 0.9783 - val_loss: 0.0772
#
# Test accuracy: 0.9769
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.98      1032
#            3       0.98      0.97      0.97      1010
#            4       0.99      0.96      0.98       982
#            5       0.98      0.97      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.97      0.97      0.97       974
#            9       0.96      0.98      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
